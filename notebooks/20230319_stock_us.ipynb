# %%
import sys
sys.path.append('..') # for import src

import os
import cloudpickle
import lzma
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import joblib
import yfinance as yf

import src
cloudpickle.register_pickle_by_value(src) # for model portability

# %%
def read_code():
    url = 'https://gist.githubusercontent.com/richmanbtc/16740d82ef2d71df8d28b7a46f156b0e/raw/092211c3fd3a1260ba12bb67eea04ff87f1b2b61/au_fr.csv'
    df = pd.read_csv(url)
    df = df.rename(columns={
        'ティッカー': 'symbol',
        '銘柄名': 'symbol_name',
        '業種': 'industry',
    })
    df['symbol_name'] = df['symbol_name'].str.normalize('NFKC')
    return df

display(read_code())
# Out:
#      symbol                             symbol_name  \
# 0         A                              AgilentTec
# 1        AA                       Alcoa Corporation
# 2       AAL            American Airlines Group Inc.
# 3      AAON                              AAON, Inc.
# 4       AAP                Advance Auto Parts, Inc.
# ...     ...                                     ...
# 1798     ZS                           Zscaler, Inc.
# 1799    ZTO           ZTO Express (Cayman) Inc. ADR
# 1800    ZTS                                  Zoetis
# 1801    ZUO                             Zuora, Inc.
# 1802    ZWS  Zurn Elkay Water Solutions Corporation
#
#                             銘柄名カナ(銘柄名カナ略称) industry
# 0                 アジレントテクノロジー(アジレントテクノロジー)     精密機器
# 1                               アルコア(アルコア)     非鉄金属
# 2       アメリカン　エアラインズ　グループ(アメリカンエアラインズグループ)      空運業
# 3                       エイエイオーエヌ(エイエイオーエヌ)       機械
# 4               アドバンス オート パーツ(アドバンスオートパーツ)      小売業
# ...                                    ...      ...
# 1798                        Ｚスケーラー(Ｚスケーラー)    サービス業
# 1799  ZTO エクスプレス (ケイマン) ADR(ZTOエクスプレスケイマン)      陸運業
# 1800                          ゾエティス(ゾエティス)      医薬品
# 1801                              ズオラ(ズオラ)    サービス業
# 1802    ザーンエルケイウォーターソリューションズ(ザーンエルケイウォーター)       機械
#
# [1803 rows x 4 columns]

# %%
df_code = read_code()
# display(df_code)

df = yf.download(df_code['symbol'].iloc[:100].tolist())
df = df.stack()
df = df.reset_index()
display(df)
# Out:
# [*********************100%***********************]  100 of 100 completed
#              Date level_1   Adj Close       Close        High         Low  \
# 0      1962-01-02      AA    1.527622    6.545672    6.583219    6.545672
# 1      1962-01-02     AEP    1.000812   34.312500   35.125000   34.312500
# 2      1962-01-03      AA    1.550988    6.645797    6.645797    6.533156
# 3      1962-01-03     AEP    0.998988   34.250000   34.750000   34.062500
# 4      1962-01-04      AA    1.550988    6.645797    6.695859    6.645797
# ...           ...     ...         ...         ...         ...         ...
# 613759 2023-03-17     AON  296.589996  296.589996  298.000000  294.690002
# 613760 2023-03-17     AOS   65.470001   65.470001   67.330002   64.980003
# 613761 2023-03-17    AOSL   24.980000   24.980000   25.950001   24.940001
# 613762 2023-03-17     APA   31.740000   31.740000   32.790001   31.430000
# 613763 2023-03-17    APAM   29.530001   29.530001   30.000000   29.290001
#
#               Open      Volume
# 0         0.000000     55930.0
# 1         0.000000      5800.0
# 2         6.545672     74906.0
# 3         0.000000     10200.0
# 4         6.645797     80899.0
# ...            ...         ...
# 613759  297.519989   2935300.0
# 613760   67.330002   2484200.0
# 613761   25.650000    689500.0
# 613762   32.689999  15840200.0
# 613763   30.000000   2705800.0
#
# [613764 rows x 8 columns]

# %%
# df = yf.download(['1301.T', '1312.T'])
df = yf.download(['1301.T'], actions=True, period='max')
display(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open    High     Low   Close    Adj Close  Volume  Dividends  \
# Date
# 2001-01-01  1400.0  1400.0  1400.0  1400.0  1339.794922       0        0.0
# 2001-01-02  1400.0  1400.0  1400.0  1400.0  1339.794922       0        0.0
# 2001-01-03  1400.0  1400.0  1400.0  1400.0  1339.794922       0        0.0
# 2001-01-04  1420.0  1420.0  1370.0  1390.0  1330.225098   19300        0.0
# 2001-01-05  1390.0  1400.0  1330.0  1330.0  1272.805298   19700        0.0
# ...            ...     ...     ...     ...          ...     ...        ...
# 2023-03-13  3610.0  3610.0  3530.0  3550.0  3550.000000   90800        0.0
# 2023-03-14  3530.0  3530.0  3455.0  3460.0  3460.000000   81000        0.0
# 2023-03-15  3505.0  3505.0  3475.0  3490.0  3490.000000   47600        0.0
# 2023-03-16  3455.0  3475.0  3415.0  3475.0  3475.000000   42500        0.0
# 2023-03-17  3475.0  3480.0  3445.0  3450.0  3450.000000   67300        0.0
#
#             Stock Splits
# Date
# 2001-01-01           0.0
# 2001-01-02           0.0
# 2001-01-03           0.0
# 2001-01-04           0.0
# 2001-01-05           0.0
# ...                  ...
# 2023-03-13           0.0
# 2023-03-14           0.0
# 2023-03-15           0.0
# 2023-03-16           0.0
# 2023-03-17           0.0
#
# [5547 rows x 8 columns]

# %%
df = yf.download(['1001.T'])
display(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - 1001.T: No timezone found, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
import time
from datetime import datetime
import gc


class Fetcher:
    def __init__(self):
        self.keys = {}
        self.data_id = 'stock_us_ohlcv'
        self.replace_mode = True
        
    def fetch(self, last_timestamp=None):
        if last_timestamp is not None and time.time() < last_timestamp + (24 + 24) * 60 * 60:
            print('no new data')
            return pd.DataFrame()
        
        df_code = read_code()
        df_code = df_code.set_index('symbol')
        
        dfs = []
        for symbols in np.array_split(df_code.index, 10):
            df = yf.download(symbols.tolist(), period='max', actions=True)
            df = df.stack()

            # for error
            df2 = yf.download(symbols.tolist(), period='max', actions=True)
            df2 = df2.stack()
            df = pd.concat([df, df2])
            df = df.loc[~df.index.duplicated()]

            if df.shape[0] == 0:
                return pd.DataFrame()

            df.reset_index(inplace=True)
            df.rename(columns={
                'Date': 'timestamp',
                'level_1': 'symbol',
                'Open': 'op',
                'High': 'hi',
                'Low': 'lo',
                'Close': 'cl',
                'Adj Close': 'adj_cl',
                'Volume': 'volume',
                'Dividends': 'dividends',
                'Stock Splits': 'splits',
                'Capital Gains': 'capital_gains',
            }, inplace=True)
            df['timestamp'] = df['timestamp'].astype(int) // 10 ** 9
            df.set_index(['timestamp', 'symbol'], inplace=True)

            df = df.join(df_code[['symbol_name', 'industry']], on='symbol', how='left')
                
            dfs.append(df)
            gc.collect()

        df = pd.concat(dfs)
        df['capital_gains'] = df['capital_gains'].fillna(0)
        df = df[[
            'op',
            'hi',
            'lo',
            'cl',
            'adj_cl',
            'volume',
            'dividends',
            'splits',
            'capital_gains',
            'symbol_name',
            'industry',
        ]]
        df.sort_index(inplace=True)
        
        return df

# %%
fetcher = Fetcher()
df = fetcher.fetch(last_timestamp=None)
display(df)
df = fetcher.fetch(last_timestamp=1600041600)
display(df)
# Out:
# [*********************100%***********************]  181 of 181 completed
# [*********************100%***********************]  181 of 181 completed
# [*********************100%***********************]  181 of 181 completed
# [*********************100%***********************]  181 of 181 completed
# [**********************60%****                   ]  108 of 181 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [10], line 2
#       1 fetcher = Fetcher()
# ----> 2 df = fetcher.fetch(last_timestamp=None)
#       3 display(df)
#       4 df = fetcher.fetch(last_timestamp=1600041600)
#
# Cell In [9], line 22, in Fetcher.fetch(self, last_timestamp)
#      20 dfs = []
#      21 for symbols in np.array_split(df_code.index, 10):
# ---> 22     df = yf.download(symbols.tolist(), period='max', actions=True)
#      23     df = df.stack()
#      25     # for error
#
# File /opt/conda/lib/python3.10/site-packages/yfinance/multi.py:129, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout)
#     122         _download_one_threaded(ticker, period=period, interval=interval,
#     123                                start=start, end=end, prepost=prepost,
#     124                                actions=actions, auto_adjust=auto_adjust,
#     125                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     126                                progress=(progress and i > 0), proxy=proxy,
#     127                                rounding=rounding, timeout=timeout)
#     128     while len(shared._DFS) < len(tickers):
# --> 129         _time.sleep(0.01)
#     131 # download synchronously
#     132 else:
#     133     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:
# [**********************74%***********            ]  134 of 181 completed

# %%
fetchers = [Fetcher()]

data = cloudpickle.dumps(fetchers)
data = lzma.compress(data)
with open('/home/jovyan/data/20230319_stock_us.xz', 'wb') as f:
    f.write(data)
